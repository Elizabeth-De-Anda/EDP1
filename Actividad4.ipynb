# %% [markdown]
# <a href="https://colab.research.google.com/github/Elizabeth-De-Anda/EDP1/blob/main/Actividad4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejemplo:

# %%
from sympy import fourier_series, pi, plot, Piecewise
from sympy.abc import x

# %%
f=Piecewise(
    (0, x < -2),
    (x+2,(x >= -2) & (x < 0)),
    (0,(x<=2)))

# %%
plot(f, (x,-2,2),line_color ='red')

# %%
s = fourier_series(f, (x, -2, 2))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, -pi, pi), show=False, legend=True)

# %%
s
# Out:
# FourierSeries(Piecewise((0, x < -2), (x + 2, x < 0), (0, x <= 2)), (x, -2, 2), (1/2, SeqFormula(Piecewise((-4*cos(_n*pi)/(_n**2*pi**2) + 4/(_n**2*pi**2), (_n > -oo) & (_n < oo) & Ne(_n, 0)), (2, True))*cos(_n*pi*x/2)/2, (_n, 1, oo)), SeqFormula(Piecewise((-4/(_n*pi) + 4*sin(_n*pi)/(_n**2*pi**2), (_n > -oo) & (_n < oo) & Ne(_n, 0)), (0, True))*sin(_n*pi*x/2)/2, (_n, 1, oo))))

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

# %%
p.show()

# %% [markdown]
# Actividad 4: Realizar las 4 gráficas en senos y cosenos

# %% [markdown]
# **Gráfica 3 en senos**

# %%
from sympy import fourier_series, pi, plot, Piecewise
from sympy.abc import x

f=Piecewise(
    (1, (0 <= x) & ( x <= pi/2)),
    (2,(pi/2 < x ) & (x <= pi)))


plot(f, (x,-2,2),line_color ='red')


s = fourier_series(f, (x, 0, pi))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, -pi, pi), show=False, legend=True)

# %%
s
# Out:
# FourierSeries(Piecewise((1, (x >= 0) & (x <= pi/2)), (2, (x <= pi) & (x > pi/2))), (x, 0, pi), (3/2, SeqFormula(2*Piecewise((-sin(_n*pi)/(2*_n) + sin(2*_n*pi)/_n, (_n > -oo) & (_n < oo) & Ne(_n, 0)), (3*pi/2, True))*cos(2*_n*x)/pi, (_n, 1, oo)), SeqFormula(2*Piecewise((cos(_n*pi)/(2*_n) - cos(2*_n*pi)/_n + 1/(2*_n), (_n > -oo) & (_n < oo) & Ne(_n, 0)), (0, True))*sin(2*_n*x)/pi, (_n, 1, oo))))

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

# %%
p.show()

# %% [markdown]
# **Gráfica 3 en cosenos**

# %%
from sympy import fourier_series, pi, plot, Piecewise
from sympy.abc import x

f=Piecewise(
    (1, (-pi <= x) & ( x <= pi/2)),
    (2,(pi/2 < x ) & (x <= pi)))


plot(f, (x,-pi,pi),line_color ='red')


s = fourier_series(f, (x, -pi, pi))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, -pi, pi), show=False, legend=True)

# %%
s
# Out:
# FourierSeries(Piecewise((1, (x >= -pi) & (x <= pi/2)), (2, (x <= pi) & (x > pi/2))), (x, -pi, pi), (5/4, SeqFormula(Piecewise((-sin(_n*pi/2)/_n + 3*sin(_n*pi)/_n, (_n > -oo) & (_n < oo) & Ne(_n, 0)), (5*pi/2, True))*cos(_n*x)/pi, (_n, 1, oo)), SeqFormula(Piecewise((cos(_n*pi/2)/_n - cos(_n*pi)/_n, (_n > -oo) & (_n < oo) & Ne(_n, 0)), (0, True))*sin(_n*x)/pi, (_n, 1, oo))))

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

# %%
p.show()

# %% [markdown]
# **Gráfica 1 en Cosenos**

# %%
from math import exp
from sympy import fourier_series, pi, plot, Piecewise, exp
from sympy.abc import x

f=Piecewise(
    (-exp(2*x), (-1 <= x) & ( x < 0)),
    (exp(2*x), (0 <= x) & ( x <= 1)))



plot(f, (x,-2,2),line_color ='red')


s = fourier_series(f, (x, -1, 1))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, -1, 1), show=False, legend=True)

# %%
s
# Out:
# FourierSeries(Piecewise((-exp(2*x), (x >= -1) & (x < 0)), (exp(2*x), (x >= 0) & (x <= 1))), (x, -1, 1), (-1/2 + exp(-2)/4 + exp(2)/4, SeqFormula((-_n*pi*exp(-2)*sin(_n*pi)/(_n**2*pi**2 + 4) + _n*pi*exp(2)*sin(_n*pi)/(_n**2*pi**2 + 4) + 2*exp(-2)*cos(_n*pi)/(_n**2*pi**2 + 4) + 2*exp(2)*cos(_n*pi)/(_n**2*pi**2 + 4) - 4/(_n**2*pi**2 + 4))*cos(_n*pi*x), (_n, 1, oo)), SeqFormula((-_n*pi*exp(2)*cos(_n*pi)/(_n**2*pi**2 + 4) - _n*pi*exp(-2)*cos(_n*pi)/(_n**2*pi**2 + 4) + 2*_n*pi/(_n**2*pi**2 + 4) - 2*exp(-2)*sin(_n*pi)/(_n**2*pi**2 + 4) + 2*exp(2)*sin(_n*pi)/(_n**2*pi**2 + 4))*sin(_n*pi*x), (_n, 1, oo))))

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

# %%
p.show()

# %% [markdown]
# **Gráfica 2 en senos**

# %%
from math import exp
from sympy import fourier_series, pi, plot, Piecewise, exp
from sympy.abc import x

f=Piecewise(
    (-exp(2*x), (-1 <= x) & ( x < 0)),
    (exp(2*x), (0 <= x) & ( x <= 1)))



plot(f, (x,-1,1),line_color ='red')


s = fourier_series(f, (x, -1, 0))
s1 = s.truncate(n = 3)
s2 = s.truncate(n = 5)
s3 = s.truncate(n = 7)
p = plot(f, s1, s2, s3, (x, -1, 0), show=False, legend=True)

# %%
s
# Out:
# FourierSeries(Piecewise((-exp(2*x), (x >= -1) & (x < 0)), (exp(2*x), (x >= 0) & (x <= 1))), (x, -1, 0), (-1/2 + exp(-2)/2, SeqFormula(2*(-_n*pi*sin(2*_n*pi)/(2*_n**2*pi**2*exp(2) + 2*exp(2)) + cos(2*_n*pi)/(2*_n**2*pi**2*exp(2) + 2*exp(2)) - 1/(2*_n**2*pi**2 + 2))*cos(2*_n*pi*x), (_n, 1, oo)), SeqFormula(2*(-_n*pi*cos(2*_n*pi)/(2*_n**2*pi**2*exp(2) + 2*exp(2)) + _n*pi/(2*_n**2*pi**2 + 2) - sin(2*_n*pi)/(2*_n**2*pi**2*exp(2) + 2*exp(2)))*sin(2*_n*pi*x), (_n, 1, oo))))

# %%
p[0].label = 'x'
p[1].label = 'n=3'
p[2].label = 'n=5'
p[3].label = 'n=7'

# %%
p.show()
